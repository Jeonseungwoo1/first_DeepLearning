# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

# %% [markdown]
# ## **Trainig and Test Datasets**

# %%
x_train = torch.FloatTensor([[1, 2, 1],
                             [1, 3, 2],
                             [1, 3, 4],
                             [1, 5, 5],
                             [1, 7, 5],
                             [1, 2, 5],
                             [1, 6, 6],
                             [1, 7, 7]
                            ])
y_train = torch.LongTensor([2, 2, 2, 1, 1, 1, 0, 0])
x_test = torch.FloatTensor([[2, 1, 1], [3, 1, 2], [3, 3, 4]])
y_test = torch.LongTensor([2, 2, 2])

# %% [markdown]
# ## **Model**

# %%
class SoftmaxClassifierModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(3,3)

  def forward(self, x):
    return self.linear(x)

# %%
model = SoftmaxClassifierModel()

# %%
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
def train(model, optimizer, x_train, y_train):
  nb_epochs = 1000
  for epoch in range(nb_epochs + 1):

    prediction = model(x_train)
    cost = F.cross_entropy(prediction, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    if epoch % 100 == 0:
      print('Epoch {:4d}/{} Cost: {:.6f}'.format(
            epoch, nb_epochs, cost.item()
        ))

# %%
def test(model, optimizer, x_test, y_test):
  prediction = model(x_test)
  prediction_classes = prediction.max(1)[1]
  correct_count = (prediction_classes == y_test).sum().item()
  cost = F.cross_entropy(prediction, y_test)

  print('Accuracy: {}% Cost: {:.6f}'.format(
         correct_count / len(y_test) * 100, cost.item()
    ))

# %%
train(model, optimizer, x_train, y_train)
# Out:
# Epoch    0/1000 Cost: 2.203667
# Epoch  100/1000 Cost: 0.720624
# Epoch  200/1000 Cost: 0.605071
# Epoch  300/1000 Cost: 0.543846
# Epoch  400/1000 Cost: 0.501460
# Epoch  500/1000 Cost: 0.468641
# Epoch  600/1000 Cost: 0.441798
# Epoch  700/1000 Cost: 0.419138
# Epoch  800/1000 Cost: 0.399604
# Epoch  900/1000 Cost: 0.382506
# Epoch 1000/1000 Cost: 0.367358

# %%
test(model, optimizer, x_test, y_test)
# Out:
# Accuracy: 100.0% Cost: 0.000766

# %% [markdown]
# ## **Learning Rate**
#
# Gradient Descent에서 (알파)값
#
# learning rate가 너무 크면 diverge하며너 점점 cost가 늘어난다.(overshooting)
#
# 너무 작으면 cost가 거의 줄어들지 않는다.

# %% [markdown]
# Data Preprocessing(데이터 전처리)
#
# 데이터를 zero-center 하고 normalize하자
